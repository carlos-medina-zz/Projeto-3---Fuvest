# %%
# Imports

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt  
# %matplotlib inline

import seaborn as sns
sns.set()

# Configurações do Pandas para dataframes
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
# Lista com o número da questão e minha resposta
my_answer = [[1, "E"],
             [2, "A"],
             [3, "E"],
             [4, "C"],
             [5, "C"],
             [6, "D"],
             [7, "A"],
             [8, "A"],
             [9, "D"],
             [10, "D"],
             [11, "B"],
             [12, "A"],
             [13, "A"],
             [14, "B"],
             [15, "A"],
             [16, "B"],
             [17, "B"],
             [18, "E"],
             [19, "C"],
             [20, "A"],
             [21, "B"],
             [22, "A"],
             [23, "A"],
             [24, "C"],
             [25, "A"],
             [26, "E"],
             [27, "E"],
             [28, "A"],
             [29, "C"],
             [30, "B"],
             [31, "B"],
             [32, "B"],
             [33, "B"],
             [34, "B"],
             [35, "A"],
             [36, "C"],
             [37, "D"],
             [38, "B"],
             [39, "C"],
             [40, "D"],
             [41, "C"],
             [42, "B"],
             [43, "E"],
             [44, "A"],
             [45, "D"],
             [46, "E"],
             [47, "C"],
             [48, "D"],
             [49, "E"],
             [50, "B"],
             [51, "B"],
             [52, "C"],
             [53, "B"],
             [54, "D"],
             [55, "D"],
             [56, "B"],
             [57, "B"],
             [58, "B"],
             [59, "B"],
             [60, "C"],
             [61, "B"],
             [62, "D"],
             [63, "C"],
             [64, "B"],
             [65, "C"],
             [66, "A"],
             [67, "D"],
             [68, "D"],
             [69, "B"],
             [70, "D"],
             [71, "A"],
             [72, "B"],
             [73, "B"],
             [74, "C"],
             [75, "B"],
             [76, "A"],
             [77, "E"],
             [78, "E"],
             [79, "B"],
             [80, "E"],
             [81, "E"],
             [82, "A"],
             [83, "D"],
             [84, "C"],
             [85, "C"],
             [86, "E"],
             [87, "E"],
             [88, "A"],
             [89, "B"],
             [90, "C"]]

# Lista com o número da questão e o gabarito
test_answer = [[1, "E", "Matemática"],
              [2, "A", "Matemática"],
              [3, "D", "Matemática"],
              [4, "C", "Matemática"],
              [5, "C", "Matemática"],
              [6, "C", "Matemática"],
              [7, "A", "Matemática"],
              [8, "D", "Matemática"],
              [9, "D", "Matemática"],
              [10, "D", "Matemática"],
              [11, "B", "Matemática"],
              [12, "A", "Matemática"],
              [13, "C", "História"],
              [14, "B", "História"],
              [15, "A", "História"],
              [16, "B", "História"],
              [17, "D", "História"],
              [18, "E", "História"],
              [19, "C", "História"],
              [20, "A", "História"],
              [21, "B", "História"],
              [22, "A", "História"],
              [23, "C", "História"],
              [24, "C", "Português"],
              [25, "C", "Literatura"],
              [26, "E", "Literatura"],
              [27, "A", "Literatura"],
              [28, "D", "Português"],
              [29, "B", "Português"],
              [30, "E", "Literatura"],
              [31, "B", "Literatura"],
              [32, "B", "Literatura"],
              [33, "E", "Literatura"],
              [34, "A", "Literatura"],
              [35, "A", "Português"],
              [36, "D", "Português"],
              [37, "D", "Português"],
              [38, "C", "Literatura"],
              [39, "C", "Literatura"],
              [40, "B", "Química"],
              [41, "C", "Química"],
              [42, "C", "Química"],
              [43, "E", "Química"],
              [44, "A", "Química"],
              [45, "D", "Química"],
              [46, "E", "Química"],
              [47, "C", "Química"],
              [48, "D", "Química"],
              [49, "E", "Química"],
              [50, "B", "Química"],
              [51, "A", "Química"],
              [52, "C", "Biologia"],
              [53, "B", "Biologia"],
              [54, "D", "Biologia"],
              [55, "C", "Biologia"],
              [56, "E", "Biologia"],
              [57, "A", "Biologia"],
              [58, "C", "Biologia"],
              [59, "B", "Biologia"],
              [60, "C", "Biologia"],
              [61, "A", "Biologia"],
              [62, "D", "Física"],
              [63, "C", "Física"],
              [64, "E", "Física"],
              [65, "C", "Física"],
              [66, "A", "Física"],
              [67, "D", "Física"],
              [68, "D", "Física"],
              [69, "A", "Física"],
              [70, "D", "Física"],
              [71, "A", "Física"],
              [72, "B", "Física"],
              [73, "B", "Inglês"],
              [74, "C", "Inglês"],
              [75, "B", "Inglês"],
              [76, "A", "Inglês"],
              [77, "E", "Inglês"],
              [78, "E", "Inglês"],
              [79, "B", "Inglês"],
              [80, "E", "Geografia"],
              [81, "E", "Geografia"],
              [82, "C", "Geografia"],
              [83, "D", "Geografia"],
              [84, "C", "Geografia"],
              [85, "D", "Geografia"],
              [86, "E", "Geografia"],
              [87, "B", "Geografia"],
              [88, "A", "Geografia"],
              [89, "B", "Geografia"],
              [90, "D", "Geografia"]]

# %%
# Cópia das minhas respostas para outra variáveis para deixá-la intacta caso necessário
answer = my_answer.copy()
counter = 0

# Nova lista com número das questões, minha resposta, resposta correta e matéria
for item in test_answer:
    answer[counter].append(item[1])
    answer[counter].append(item[2])
    counter += 1

# Label das colunas
columns = ["Questão", "Minha resposta", "Resposta correta", "Matéria"]

# %%
# Cria o dataframe
df = pd.DataFrame(np.array(answer), columns = columns)

# Cria uma nova coluna com True caso tenha acertado a questão e False caso tenha errado
df["Acertei questão"] = np.where(df["Minha resposta"] == df["Resposta correta"], True, False)

# %%
subjects = ["Matemática", "História", "Português", "Literatura", "Química",
            "Biologia", "Física", "Inglês", "Geografia"]

# Lista de listas que irá receber em cada elemento:
# Nome da matéria, quantidade de questões, quantidade de acertos, porcentagem de acertos
grades_list = [ [] for i in range(len(subjects)) ]

counter = 0
for subject in subjects:
    
    # Primeiro elemento recebe o nome da matéria
    grades_list[counter].append(subject)
    
    # Segundo elemento recebe a quantidade de questões
    df_subject = df.query('Matéria == @subject')
    len_subject = len(df_subject)
    grades_list[counter].append(len_subject)
    
    # Terceiro elemento recebe a quantidade de acertos
    mask = df_subject["Acertei questão"] == True
    rights_subject = len(df_subject[mask])
    grades_list[counter].append(rights_subject)
    
    # Quarto elemento recebe a porcentagem de acertos
    percentage_subject = int(100 * (rights_subject/len_subject))
    grades_list[counter].append(percentage_subject)
    
    counter += 1

# %%
total_rights = 0

# Print dos acertos, total de questões e porcentagem de acertos de cada matéria

print("Dados da minha Fuvest 2020\n")

for item in grades_list:
    print("{0}: Acertei {1} de {2} questões => {3}%" .format(item[0], item[2], item[1], item[3]))
    total_rights = total_rights + item[2]

print("\nAcertei {} questões de {}." .format(total_rights, len(df)))
# Out:
# Dados da minha Fuvest 2020
#
# Matemática: Acertei 9 de 12 questões => 75%
# História: Acertei 8 de 11 questões => 72%
# Português: Acertei 3 de 6 questões => 50%
# Literatura: Acertei 4 de 10 questões => 40%
# Química: Acertei 9 de 12 questões => 75%
# Biologia: Acertei 5 de 10 questões => 50%
# Física: Acertei 9 de 11 questões => 81%
# Inglês: Acertei 7 de 7 questões => 100%
# Geografia: Acertei 7 de 11 questões => 63%
#
# Acertei 61 questões de 90.

# %%
columns_fuvest = ["Matéria", "Total de questões", "Total de acertos", "Porcentagem de acertos"]

df_my_fuvest = pd.DataFrame(np.array(grades_list), columns = columns_fuvest)

# Converte todos os valores do df, com exceção da coluna "Matéria, para float
for item in columns_fuvest:
    if item == "Matéria":
        pass
    else:
        df_my_fuvest[item] = df_my_fuvest[item].astype(float)

# Ordena o df em ordem decrescente         
df_my_fuvest = df_my_fuvest.sort_values(by = ["Porcentagem de acertos"], ascending = False)

# Plot
plt.figure(figsize = (16, 6))
ax = sns.barplot(x="Matéria", y="Porcentagem de acertos", data=df_my_fuvest)
ax.axes.set_title("Porcentagem de acertos por matéria", fontsize=20)
ax.set_xlabel("Matéria", fontsize=15)
ax.set_ylabel("Porcentagem de acertos", fontsize=15)

# Colocando o número da porcentagem de acertos em cima de cada barra
initialx= -0.9
for p in ax.patches:
    ax.text(p.get_width() + initialx, p.get_height(),"{:1.0f}%".format(p.get_height()))
    initialx+=1

plt.show()
